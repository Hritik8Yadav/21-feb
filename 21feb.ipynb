# %% [markdown]
# ![Q1.jpg](attachment:af73629b-fffb-432e-976c-6f7230093c91.jpg)

# %%
#Ans1: Web Scraping is the way to infer some useful data from a website by using the infering tools such as python.
#    It is used to apply some calculation on that data and take the decisions accordingly.
#    data analytics
#    machine learning
#    digital marketing

# %% [markdown]
# ![Q2.jpg](attachment:ce7ba546-09e7-4a6b-a07b-137c322ba020.jpg)

# %%
#Ans2: The different methods used in web scraping are:-
#        Copy-paste method
#        pattern matching
#        machine learning
#        HTML parsing

# %% [markdown]
# ![Q3.jpg](attachment:8e7f6e43-f2b8-4c2a-afb9-3cbf187a7afd.jpg)

# %%
#Ans3: Beautiful Soup is a module of python module used to extract data from the a html file. 
#    It contains methods to apply on a html file and with the help of these methods we can convert the html code in readable format by the python.
#    It is used because when a html file is opened in the python, the format of the file is not arranged so it can't be read by python without arranging the data

# %% [markdown]
# ![Q4.jpg](attachment:9c34577a-bd17-4108-be98-84dc0129ac27.jpg)

# %%
#Ans 4: flask is a module of the python used to create the web APIs in the python.
#    So it provide the platform to interact the webpage and the python code of the web scraping, if we want that data which is coming from the webscraping
#    to show on a website this can be done easily by using flask API.
#    In this project we scrapped the flipkart website then we created a website and we show that scrapped data on the website by using the flask API.

# %% [markdown]
# ![Q5.jpg](attachment:e1a38a23-1e34-4ef9-9019-897f5f9a9519.jpg)

# %%
#Ans5: The two services AWS are used in this project:
#        (i). CodePipeline:- It is a AWS product to build the pipeline of code to be run in the AWS. It is directly connected to the github and take the code from there and deliver to the beanstalk.
#        (ii). Elastic Beanstalk:- It is a virtual environment of the harware required to run an application It include all the necessary resources required by an application.
